# %%
import keras
from keras.optimizers import RMSprop
import keras.backend as K
from tqdm import tqdm

# %%
import codecs
with codecs.open("neg_small.txt", "rb", encoding="utf-8", errors="ignore") as f:
    lines = f.read().split("\n")
    neg_text = []
    for line in lines:
        data = line.split("\n")[0]
        neg_text.append(data)

# %%
len(neg_text)
# Out:
# 100000

# %%
with codecs.open("pos_small.txt", "rb", encoding="utf-8", errors="ignore") as f:
    lines = f.read().split("\n")
    pos_text = []
    for line in lines:
        data = line.split("\n")[0]
        pos_text.append(data)

# %%
len(pos_text)
# Out:
# 100000

# %%
pos_text
# Out:
# ['great service! corey is very service oriented.',
#  'works fast and very effiecient with his time.',
#  'highly recommended.',
#  "found the perfect piece for the retro look i'm going for.",
#  'shawn did a great job.',
#  'keep up the good work! i will definitely be back.',
#  'what a great place! modern on melrose has amazing furniture at great prices.',
#  'a hidden gem! found a beautiful buffet for a great price.',
#  'this place is a great for those vintage/mid century modern finds.',
#  'from clothing to couches they have it all and great prices too.',
#  'we will always check back at melrose when looking for unique pieces for our home.',
#  'great items at a good price.',
#  'helpful, easy to deal with owners.',
#  'modern on melrose is one of our favorite shops on la curva.',
#  'i loved it.',
#  'the classic burger is amazing.',
#  "we'll definitely go back.",
#  "the food is really good for bar food, and it's very reasonably priced.",
# ...

# %%
punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~|+=''' 
import regex as re
for i in range(len(pos_text)):
#     print(i)
    pos_text[i] = pos_text[i].lower()
    for x in pos_text[i].lower(): 
#         print(re.search(r'[0-9a-zA-Z]', x))
        
        if re.search(r'[0-9a-zA-Z\s]', x) is None: 
            pos_text[i] = pos_text[i].replace(x, "") 
for i in range(len(neg_text)):
#     print(i)
    neg_text[i] = neg_text[i].lower()
    for x in neg_text[i].lower(): 
        if x not in r'\w': 
            neg_text[i] = neg_text[i].replace(x, "") 
    # Print string without punctuation 
#     print(i) 

# i = i.replace(punctuations, '')

# %%
pos_text
# Out:
# ['great service corey is very service oriented',
#  'works fast and very effiecient with his time',
#  'highly recommended',
#  'found the perfect piece for the retro look im going for',
#  'shawn did a great job',
#  'keep up the good work i will definitely be back',
#  'what a great place modern on melrose has amazing furniture at great prices',
#  'a hidden gem found a beautiful buffet for a great price',
#  'this place is a great for those vintagemid century modern finds',
#  'from clothing to couches they have it all and great prices too',
#  'we will always check back at melrose when looking for unique pieces for our home',
#  'great items at a good price',
#  'helpful easy to deal with owners',
#  'modern on melrose is one of our favorite shops on la curva',
#  'i loved it',
#  'the classic burger is amazing',
#  'well definitely go back',
#  'the food is really good for bar food and its very reasonably priced',
#  'the place is awesome im there every weekend',
# ...

# %%
full_text = pos_text + neg_text
print(full_text[:10])
print(len(full_text))
dictionary = []
for text in full_text:
    words = text.split()
#     punctuationRemover.tokenize(text)
    for i in range(0, len(words)):
        if words[i] not in dictionary:
            dictionary.append(words[i])
# Out:
# ['great service corey is very service oriented', 'works fast and very effiecient with his time', 'highly recommended', 'found the perfect piece for the retro look im going for', 'shawn did a great job', 'keep up the good work i will definitely be back', 'what a great place modern on melrose has amazing furniture at great prices', 'a hidden gem found a beautiful buffet for a great price', 'this place is a great for those vintagemid century modern finds', 'from clothing to couches they have it all and great prices too']
# 200000

# %%
len(dictionary)
# Out:
# 27253

# %%
from keras.preprocessing.text import Tokenizer
VOCAB_SIZE = len(dictionary)
tokenizer = Tokenizer()
# print(VOCAB_SIZE)

# %%
tokenizer.fit_on_texts(full_text)
word_index = tokenizer.word_index
len(word_index)
# Out:
# 27251

# %%
index2word = {}
for i in range(len(dictionary)):
    if i < VOCAB_SIZE + 1:
        index2word[i] = dictionary[i]
    if i > VOCAB_SIZE + 1:
        continue

# %%
word2index = {}
for k, v in index2word.items():
    word2index[v] = k

# %%
len(word2index)
# Out:
# 27253

# %%
neg_sequences = tokenizer.texts_to_sequences(neg_text)

# %%
pos_sequences = tokenizer.texts_to_sequences(pos_text)

# %%
import numpy as np
MAX_LEN = 15
# num_samples = len(encoder_sequences)
# decoder_output_data = np.zeros((num_samples, MAX_LEN, VOCAB_SIZE), dtype="float32")

# %%
from keras.preprocessing.sequence import pad_sequences
neg_data = pad_sequences(neg_sequences, maxlen=MAX_LEN, dtype='int32', padding='post', truncating='post')
pos_data = pad_sequences(pos_sequences, maxlen=MAX_LEN, dtype='int32', padding='post', truncating='post')

# %%
pos_data[0]
# Out:
# array([   7,   21, 7047,    4,   11,   21, 1506,    0,    0,    0,    0,
#           0,    0,    0,    0])

# %%
embeddings_index = {}
with open('glove.6B.200d.txt', encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()

print("Glove Loded!")
len(embeddings_index)
# Out:
# Glove Loded!
# 400000

# %%
embedding_dimention = 200
def embedding_matrix_creater(embedding_dimention, word_index):
    embedding_matrix = np.zeros((len(word_index) + 1, embedding_dimention))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
          # words not found in embedding index will be all-zeros.
            embedding_matrix[i] = embedding_vector
    return embedding_matrix

# %%
embedding_matrix = embedding_matrix_creater(200, word_index=word2index)

# %% [markdown]
# # Generator model

# %%
from keras.layers import Embedding
from keras.layers import Input, Dense, LSTM, TimeDistributed
from keras.models import Model

# %%
embed_layer = Embedding(input_dim=VOCAB_SIZE + 1, output_dim=200, trainable=True,)
embed_layer.build((None,))
embed_layer.set_weights([embedding_matrix])
# Out:
# WARNING:tensorflow:From C:\Programming_Software\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
VOCAB_SIZE
# Out:
# 27253

# %%
from keras.models import Sequential
from keras.layers import RepeatVector, Flatten,GRU

class WGANGP():
    def __init__(self, MAX_LEN, VOCAB_SIZE):
        self.n_critic = 5
        optimizer = RMSprop(lr=0.00005)
        self.MAX_LEN = MAX_LEN
        self.VOCAB_SIZE = VOCAB_SIZE
        self.discriminator = self.discriminator_model()
        self.generator = self.generator_model()
        self.discriminator.compile(loss =self.wasserstein_loss, optimizer = 'adam' )
        self.generator.compile(loss ='mean_squared_error', optimizer = 'adam' )
        
    
    def discriminator_model(self):
        model = Sequential()
        model.add(Embedding(VOCAB_SIZE,output_dim=200,input_length=15))
        model.add(GRU(units=32,dropout=0.2,recurrent_dropout=0.2))
        model.add(Dense(1,activation="sigmoid"))
#         model.add(Input(shape=(15,200)))
#         model.add(Embedding(input_dim=100000 + 1, output_dim=200))
#         model.add(Dense(1024, activation='relu', input_dim=200))
# #         model.add(Flatten(shape=(200,)))
#         model.add(Dense(1, activation='sigmoid'))
        
#         print(model.summary())
        
        return model
    
    def generator_model(self):
        
#         model = Sequential()
        
#         encoder_inputs = Input(shape=(MAX_LEN, ), dtype='int32',)
#         encoder_embedding = embed_layer(encoder_inputs)
#         encoder_LSTM = LSTM(1500, return_state=True, return_sequences=True)
#         LSTM2 = LSTM(1000, return_state=True, return_sequences=True)
#         decode_LSTM = LSTM(500, return_state=True, return_sequences=True)
#         output = Dense(200, activation='softmax')
        
#         encoder_outputs, state_h, state_c = encoder_LSTM(encoder_embedding)
#         LSTM2_output, state2_h, state2_c = LSTM2(encoder_outputs)
#         output = Dense(200, activation='softmax')
#         model = Model(encoder_inputs, output)

        inputs = Input(shape=(MAX_LEN,))
        encoder1 = embed_layer(inputs)
        encoder2 = LSTM(1000, return_sequences=True)(encoder1)
        encoder4 = LSTM(500)(encoder2)
        encoder3 = RepeatVector(MAX_LEN)(encoder4)
        # decoder output model
        decoder1 = LSTM(500, return_sequences=True)(encoder3)
        outputs = Dense(200, activation='softmax')(decoder1)
        # tie it together
        model = Model(inputs=inputs, outputs=outputs)
#         model.compile(loss='categorical_crossentropy', optimizer='adam')
        
        
#         model.add(Input(shape=(MAX_LEN, )))
#         model.add(embed_layer)
#         model.add(LSTM(1500, return_sequences=True, input_shape=()))
#         model.add(LSTM(1000, return_sequences=True))
#         model.add(LSTM,)
        
        print(model.summary())
#         print(encoder_outputs.shape)


#         decoder_inputs = Input(shape=(MAX_LEN, ), dtype='int32',)
#         decoder_embedding = embed_layer(decoder_inputs)
#         print("\n-------"+str(decoder_embedding))
#         decoder_LSTM = LSTM(HIDDEN_DIM, return_state=True, return_sequences=True)
#         decoder_outputs, _, _ = decoder_LSTM(encoder_outputs, initial_state=[state_h, state_c])

#         dense_layer = Dense(VOCAB_SIZE, activation='softmax')
#         outputs = TimeDistributed(Dense(VOCAB_SIZE, activation='softmax'))(decoder_outputs)
#         model = Model([encoder_inputs, decoder_inputs], outputs)
#         print(model.summary())

        return model

    def wasserstein_loss(self, y_true, y_pred):
        return K.mean(y_true * y_pred)
#     def wasserstein_loss_gp(self,true, y_pred):
        
    
    
    def train(self, epochs=1, batch_size=10, sample_interval=50):

        # Load the dataset
#         (X_train, _), (_, _) = mnist.load_data()

        # Rescale -1 to 1
        X_train = 
        
        print(pos_data.shape)
        print(neg_data.shape)
        print(X_train.shape)
        y_train =np.concatenate(( np.ones(pos_data.shape[0]), np.zeros(neg_data.shape[0])), axis=0)
        print(X_train.shape)
        print(y_train.shape)
#         neg_list = [0]*len(neg_data)
#         y_train.extend(neg_list)
#         X_train = np.expand_dims(X_train, axis=3)

        # Adversarial ground truths
#         valid = -np.ones((batch_size, 1))
#         fake =  np.ones((batch_size, 1))
#         dummy = np.zeros((batch_size, 1)) # Dummy gt for gradient penalty
        for epoch in tqdm(range(epochs)):

#             break
            # ---------------------
            #  Train Discriminator
            # ---------------------

            # Select a random batch of images
#             idx = np.random.randint(0, X_train.shape[0], batch_size)
#             imgs = X_train[idx]
            # Sample generator input
#             noise = np.random.normal(0, 1, (batch_size, self.latent_dim))
            # Train the critic
            d_loss = self.discriminator.fit(X_train, y_train, batch_size=32)

            # ---------------------
            #  Train Generator
            # ---------------------

#             g_loss = self.generator_model.train_on_batch(noise, valid)

#             # Plot the progress
#             print ("%d [D loss: %f] [G loss: %f]" % (epoch, d_loss[0], g_loss))

#             # If at save interval => save generated image samples
#             if epoch % sample_interval == 0:
#                 self.sample_images(epoch)

# %%
wganGP_model = WGANGP(15, VOCAB_SIZE=VOCAB_SIZE)
wganGP_model.discriminator_model()
wganGP_model.train()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_6 (InputLayer)         (None, 15)                0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 15, 200)           5450800
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 15, 1000)          4804000
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 500)               3002000
# _________________________________________________________________
# repeat_vector_6 (RepeatVecto (None, 15, 500)           0
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 15, 500)           2002000
# _________________________________________________________________
# dense_17 (Dense)             (None, 15, 200)           100200
# ...

# %%
wganGP_model.discriminator_model()
